# %%
import pandas as pd

def add_full_name(path_to_csv, path_to_new_csv):   
    baseball_data = pd.read_csv(path_to_csv)

    baseball_data['nameFull'] = baseball_data['nameFirst'] + ' ' + baseball_data['nameLast']
    baseball_data.to_csv(path_to_new_csv)
    print(baseball_data.head(10))

add_full_name('./Master.csv', './Master_v2.csv')
# Out:
#    lahmanID   playerID managerID  ...    holtzID    bbrefID        nameFull
# 0         1  aaronha01       NaN  ...  aaronha01  aaronha01      Hank Aaron
# 1         2  aaronto01       NaN  ...  aaronto01  aaronto01    Tommie Aaron
# 2         3   aasedo01       NaN  ...   aasedo01   aasedo01        Don Aase
# 3         4   abadan01       NaN  ...   abadan01   abadan01       Andy Abad
# 4         5  abadijo01       NaN  ...  abadijo01  abadijo01     John Abadie
# 5         6  abbated01       NaN  ...  abbated01  abbated01  Ed Abbaticchio
# 6         7  abbeybe01       NaN  ...  abbeybe01  abbeybe01      Bert Abbey
# 7         8  abbeych01       NaN  ...  abbeych01  abbeych01   Charlie Abbey
# 8         9  abbotda01       NaN  ...  abbotda01  abbotda01      Dan Abbott
# 9        10  abbotfr01       NaN  ...  abbotfr01  abbotfr01     Fred Abbott
#
# [10 rows x 34 columns]
